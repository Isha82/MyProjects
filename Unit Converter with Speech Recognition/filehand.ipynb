# %%
f= open("unitconverterfile.txt","w+")

# %%
f=open("unitconverterfile.txt","a+")

# %%
import pyaudio
import speech_recognition as sr
r = sr.Recognizer()
def weight(s):
    b=1
    l=s.split(" ")
    list1=["1000","microgram","0.01","g","0.000002","lb","0.000001","kg","0.000035","oz"]
    list2=["0.001","mg","0.0000000022","lb","0.000001","g","0.0000000001","kg","0.000000035","oz"]
    list3=["1000000","microgram","1000","mg","0.001","kg","0.002205","lb","0.035274","oz"]
    list4=["453.592","g","0.4535","kg","453592370","microgram","453592.37","mg","16","oz"]
    list5=["1000000000","microgram","1000000","mg","1000","g","2.204623","lb","35.2739","oz"]
    list6=["28349523","microgram","28349.523","mg","28.349","g","0.02835","kg","0.0625","lb"]
    a=float(l[0])
    if(l[1].casefold()=="mg"):
        for i in range(0,10,2):
            print(str(a*float(list1[i]))+" "+list1[b])
            x=str(a*float(list1[i]))+" "+list1[b]
            f=open("unitconverterfile","a+")
            f.write("\n"+x+"\n")
            b=b+2
    
    elif(l[1].casefold()=="microgram"):
        for i in range(0,10,2):
            print(str(a*float(list2[i]))+" "+list2[b])
            x=str(a*float(list2[i]))+" "+list2[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="g"):
        for i in range(0,10,2):
            print(str(a*float(list3[i]))+" "+list3[b])
            x=str(a*float(list3[i]))+" "+list3[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="lb"):
        for i in range(0,10,2):
            print(str(a*float(list4[i]))+" "+list4[b])
            x=str(a*float(list4[i]))+" "+list4[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="kg"):
        for i in range(0,10,2):
            print(str(a*float(list5[i]))+" "+list5[b])
            x=str(a*float(list5[i]))+" "+list5[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="oz"):
        for i in range(0,10,2):
            print(str(a*float(list6[i]))+" "+list6[b])
            x=str(a*float(list6[i]))+" "+list6[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
def length(s):
    b=1
    l=s.split(" ")
    list1=["10000","micrometer","10","mm","0.1","dm","0.00001","km","0.01","m"]
    list2=["0.0001","cm","0.001","mm","0.00001","dm","0.000000001","km","0.000001","m"]
    list3=["1000","micrometer","0.1","cm","0.01","dm","0.000001","km","0.001","m"]
    list4=["100000","micrometer","100","mm","10","cm","0.0001","km","0.1","m"]
    list5=["1000000000","micrometer","1000000","mm","100000","cm","10000","dm","1000","m"]
    list6=["1000000","micrometer","1000","mm","100","cm","10","dm","0.001","km"]
    a=float(l[0])
    if(l[1].casefold()=="cm"):
        for i in range(0,9,2):
            print(str(a*float(list1[i]))+" "+list1[b])
            x=str(a*float(list1[i]))+" "+list1[b]
            f=open("unitconverterfile","a+")
            f.write("\n"+x+"\n")
            b=b+2
    if(l[1].casefold()=="micrometer"):
        for i in range(0,9,2):
            print(str(a*float(list2[i]))+" "+list2[b])
            x=str(a*float(list2[i]))+" "+list2[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="mm"):
        for i in range(0,9,2):
            print(str(a*float(list3[i]))+" "+list3[b])
            x=str(a*float(list3[i]))+" "+list3[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="dm"):
        for i in range(0,9,2):
            print(str(a*float(list4[i]))+" "+list4[b])
            x=str(a*float(list4[i]))+" "+list4[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="km"):
        for i in range(0,9,2):
            print(str(a*float(list5[i]))+" "+list5[b])
            x=str(a*float(list5[i]))+" "+list5[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="m"):
        for i in range(0,9,2):
            print(str(a*float(list6[i]))+" "+list6[b])
            x=str(a*float(list6[i]))+" "+list6[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
def volume(s):
    b=1
    l=s.split(" ")
    list1=["0.001","L","1000","mm^3","1","cm^3","0.001","dm^3","0.000001","m^3"]
    list2=["1000","ml","1000000","mm^3","1000","cm^3","1","dm^3","0.001","m^3"]
    list3=["0.001","ml","0.000001","L","0.001","cm^3","0.000001","dm^3","0.000000001","m^3"]
    list4=["1","ml","0.001","L","1000","mm^3","0.001","dm^3","0.000001","m^3"]
    list5=["1000","ml","1","L","1000000","mm^3","1000","cm^3","0.001","m^3"]
    list6=["1000000","ml","1000","L","1000000000","mm^3","1000000","cm^3","1000","dm^3"]
    a=float(l[0])
    if(l[1].casefold()=="ml"):
        for i in range(0,10,2):
            print(str(a*float(list1[i]))+" "+list1[b])
            x=str(a*float(list1[i]))+" "+list1[b]
            f=open("unitconverterfile","a+")
            f.write("\n"+x+"\n")
            b=b+2
    
    elif(l[1].casefold()=="l"):
        for i in range(0,10,2):
            print(str(a*float(list2[i]))+" "+list2[b])
            x=str(a*float(list2[i]))+" "+list2[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="mm^3"):
        for i in range(0,10,2):
            print(str(a*float(list3[i]))+" "+list3[b])
            x=str(a*float(list3[i]))+" "+list3[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="cm^3"):
        for i in range(0,10,2):
            print(str(a*float(list4[i]))+" "+list4[b])
            x=str(a*float(list4[i]))+" "+list4[b]
            f=open("unitconverterfile","a+")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="dm^3"):
        for i in range(0,10,2):
            print(str(a*float(list5[i]))+" "+list5[b])
            x=str(a*float(list5[i]))+" "+list5[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="m^3"):
        for i in range(0,10,2):
            print(str(a*float(list6[i]))+" "+list6[b])
            x=str(a*float(list6[i]))+" "+list6[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
def area(s):
    b=1
    l=s.split(" ")
    list1=["0.01","cm^2","0.0001","dm^2","0.000001","m^2","0.000000000001","km^2"]
    list2=["100","mm^2","0.01","dm^2","0.0001","m^2","0.0000000001","km^2"]
    list3=["10000","mm^2","100","cm^2","0.01","m^2","0.00000001","km^2"]
    list4=["1000000","mm^2","10000","cm^2","100","dm^2","0.000001","km^2"]
    list5=["1000000000000","mm^2","10000000000","cm^2","100000000","dm^2","1000000","m^2"]
   
    a=float(l[0])
    if(l[1].casefold()=="mm^2"):
        for i in range(0,8,2):
            print(str(a*float(list1[i]))+" "+list1[b])
            x=str(a*float(list1[i]))+" "+list1[b]
            f=open("unitconverterfile","a")
            f.write("\n"+x+"\n")
            b=b+2
    
    elif(l[1].casefold()=="cm^2"):
        for i in range(0,8,2):
            print(str(a*float(list2[i]))+" "+list2[b])
            x=str(a*float(list2[i]))+" "+list2[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="dm^2"):
        for i in range(0,8,2):
            print(str(a*float(list3[i]))+" "+list3[b])
            x=str(a*float(list3[i]))+" "+list3[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="m^2"):
        for i in range(0,8,2):
            print(str(a*float(list4[i]))+" "+list4[b])
            x=str(a*float(list4[i]))+" "+list4[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="km^2"):
        for i in range(0,8,2):
            print(str(a*float(list5[i]))+" "+list5[b])
            x=str(a*float(list5[i]))+" "+list5[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2                   
def currency(s):
    b=1
    l=s.split(" ")
    list1=["0.01","USD","0.01","EUR","1.57","JPY","0.02","AUD"]
    list2=["68.86","INR","0.89","EUR","107.78","JPY","1.42","AUD"]
    list3=["77.30","INR","1.12","USD","120.99","JPY","1.59","AUD"]
    list4=["0.64","INR","0.01","USD","0.01","EUR","0.01","AUD"]
    list5=["48.49","INR","0.70","USD","0.63","EUR","75.89","AUD"]
   
    a=float(l[0])
    if(l[1].casefold()=="inr"):
        for i in range(0,8,2):
            print(str(a*float(list1[i]))+" "+list1[b])
            x=str(a*float(list1[i]))+" "+list1[b]
            f=open("unitconverterfile","a")
            f.write("\n"+x+"\n")
            b=b+2
    
    elif(l[1].casefold()=="usd"):
        for i in range(0,8,2):
            print(str(a*float(list2[i]))+" "+list2[b])
            x=str(a*float(list2[i]))+" "+list2[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="eur"):
        for i in range(0,8,2):
            print(str(a*float(list3[i]))+" "+list3[b])
            x=str(a*float(list3[i]))+" "+list3[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="jpy"):
        for i in range(0,8,2):
            print(str(a*float(list4[i]))+" "+list4[b])
            x=str(a*float(list4[i]))+" "+list4[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="aud"):
        for i in range(0,8,2):
            print(str(a*float(list5[i]))+" "+list5[b])
            x=str(a*float(list5[i]))+" "+list5[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
def time(s):
    b=1
    l=s.split(" ")
    list1=["0.001","sec","0.000017","min","0.000000277","hour","1.1574e-8","day","1.6534e-9","week","3.805e-10","month","3.171e-11","year"]
    list2=["1000","ms","0.0166","min","0.000278","hour","0.000012","day","0.000002","week","3,805e-7","month","3.171e-8","year"]
    list3=["60000","ms","60","sec","0.01667","hour","0.000694","day","0.000099","week","0.000023","month","0.000002","year"]
    list4=["3600000","ms","3600","sec","60","min","0.041","day","0.00595","week","0.00137","month","0.000114","year"]
    list5=["86400000","ms","86400","sec","1440","min","24","hour","0.142857","week","0.032877","month","0.00274","year"]
    list6=["604800000","ms","604800","sec","10080","min","168","hour","7","day","0.2301","month","0.01917","year"]
    list7=["2628000000","ms","2628000","sec","43800","min","730","hour","30.41","day","4.345","week","0.0833","year"]
    list8=["3.154e+10","ms","31536000","sec","525600","min","8760","hour","365","day","52.142","week","12","month"]
    a=float(l[0])
    if(l[1].casefold()=="ms"):
        for i in range(0,14,2):
            print(str(a*float(list1[i]))+" "+list1[b])
            x=str(a*float(list1[i]))+" "+list1[b]
            f=open("unitconverterfile","a")
            f.write("\n"+x+"\n")
            b=b+2
    
    elif(l[1].casefold()=="sec"):
        for i in range(0,14,2):
            print(str(a*float(list2[i]))+" "+list2[b])
            x=str(a*float(list2[i]))+" "+list2[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="min"):
        for i in range(0,14,2):
            print(str(a*float(list3[i]))+" "+list3[b])
            x=str(a*float(list3[i]))+" "+list3[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="hour"):
        for i in range(0,14,2):
            print(str(a*float(list4[i]))+" "+list4[b])
            x=str(a*float(list4[i]))+" "+list4[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="day"):
        for i in range(0,14,2):
            print(str(a*float(list5[i]))+" "+list5[b])
            x=str(a*float(list5[i]))+" "+list5[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="week"):
        for i in range(0,14,2):
            print(str(a*float(list6[i]))+" "+list6[b])
            x=str(a*float(list6[i]))+" "+list6[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="month"):
        for i in range(0,14,2):
            print(str(a*float(list7[i]))+" "+list7[b])
            x=str(a*float(list7[i]))+" "+list7[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="year"):
        for i in range(0,14,2):
            print(str(a*float(list8[i]))+" "+list8[b])
            x=str(a*float(list8[i]))+" "+list8[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
def speed(s):
    b=1
    l=s.split(" ")
    list1=["0.001","km/s","60","m/min","0.06","km/min","3.6","km/h","2.236","mi/h"]
    list2=["1000","m/s","60000","m/min","60","km/min","3600","km/h","2236.93","mi/h"]
    list3=["0.0166","m/s","0.000017","km/s","0.001","km/min","0.06","km/h","0.037282","mi/h"]
    list4=["16.667","m/s","0.01667","km/s","1000","m/min","60","km/h","37.2822","mi/h"]
    list5=["0.2777","m/s","0.000278","km/s","16.6667","m/min","0.01667","km/min","0.62137","mi/h"]
    list6=["0.4470","m/s","0.00047","km/s","26.822","m/min","0.02682","km/min","1.60934","km/h"]
    a=float(l[0])
    if(l[1].casefold()=="m/s"):
        for i in range(0,10,2):
            print(str(a*float(list1[i]))+" "+list1[b])
            x=str(a*float(list1[i]))+" "+list1[b]
            f=open("unitconverterfile","a")
            f.write("\n"+x+"\n")
            b=b+2
    
    elif(l[1].casefold()=="km/s"):
        for i in range(0,10,2):
            print(str(a*float(list2[i]))+" "+list2[b])
            x=str(a*float(list2[i]))+" "+list2[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="m/min"):
        for i in range(0,10,2):
            print(str(a*float(list3[i]))+" "+list3[b])
            x=str(a*float(list3[i]))+" "+list3[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="km/min"):
        for i in range(0,10,2):
            print(str(a*float(list4[i]))+" "+list4[b])
            x=str(a*float(list4[i]))+" "+list4[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="km/h"):
        for i in range(0,10,2):
            print(str(a*float(list5[i]))+" "+list5[b])
            x=str(a*float(list5[i]))+" "+list5[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="mi/h"):
        for i in range(0,10,2):
            print(str(a*float(list6[i]))+" "+list6[b])
            x=str(a*float(list6[i]))+" "+list6[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
def force(s):
    b=1
    l=s.split(" ")
    list1=["0.00001","N","1.0e-8","kN","0.000001","kgf","0.000002","lbf"]
    list2=["100000","dyn","0.001","kN","0.101972","kgf","0.2248","lbf"]
    list3=["100000000","dyn","1000","N","101.9716","kgf","224.8089","lbf"]
    list4=["980665","dyn","9.80665","N","0.009807","kN","2.204","lbf"]
    list5=["444822.16","dyn","4.448222","N","0.00448","kN","0.453592","kgf"]
   
    a=float(l[0])
    if(l[1].casefold()=="dyn"):
        for i in range(0,8,2):
            print(str(a*float(list1[i]))+" "+list1[b])
            x=str(a*float(list1[i]))+" "+list1[b]
            f=open("unitconverterfile","a")
            f.write("\n"+x+"\n")
            b=b+2
    
    elif(l[1].casefold()=="n"):
        for i in range(0,8,2):
            print(str(a*float(list2[i]))+" "+list2[b])
            x=str(a*float(list2[i]))+" "+list2[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="kn"):
        for i in range(0,8,2):
            print(str(a*float(list3[i]))+" "+list3[b])
            x=str(a*float(list3[i]))+" "+list3[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="kgf"):
        for i in range(0,8,2):
            print(str(a*float(list4[i]))+" "+list4[b])
            x=str(a*float(list4[i]))+" "+list4[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    elif(l[1].casefold()=="lbf"):
        for i in range(0,8,2):
            print(str(a*float(list5[i]))+" "+list5[b])
            x=str(a*float(list5[i]))+" "+list5[b]
            f=open("unitconverterfile","a")
            f.write(x+"\n")
            b=b+2
    

    
    
    
print("""The following converters are available:
Length Converter
Weight converter
Volume Converter
Area Converter
Currency Converter
Time Converter
Force Converter""")
print("If you want to use speech recognition enter 0 if not enter any other key")
ch=int(input())
v=0
if(ch==0):
    print("Speak now")
    print("which converter you want to use ")
    with sr.Microphone() as source:
        audio = r.listen(source) 
    try:
        a=(r.recognize_google(audio,key=None,language="en-GB",show_all=False))
        print(a)
    except sr.UnknownValueError:
        a=("could not understand audio")
        print(a)
    except NameError:
        a=("could not understand audio")
        print(a)
    except LookupError:                            
        a=("Could not understand audio")
        print(a)
    if(a=="length converter"):
        print("The value to be converted is")
        with sr.Microphone() as source:
            audi = r.listen(source) 
        try:
            s=(r.recognize_google(audi,key=None,language="en-GB",show_all=False))
            print(s)
            f=open("unitconverterfile","a")
            f.write(s+"\n")
                   
        except sr.UnknownValueError:
            s=("could not understand audio")
            print(s)
        except NameError:
            s=("could not understand audio")
            print(s)
        except LookupError:                            
            s=("Could not understand audio")
            print(s)
        length(s)
    if(a=="weight converter"):
        print("The value to be converted is")
        with sr.Microphone() as source:
            audi = r.listen(source) 
        try:
            s=(r.recognize_google(audi,key=None,language="en-GB",show_all=False))
            print(s)
            f=open("unitconverterfile","a")
            f.write(s+"\n")
        except sr.UnknownValueError:
            s=("could not understand audio")
            print(s)
        except NameError:
            s=("could not understand audio")
            print(s)
        except LookupError:                            
            s=("Could not understand audio")
            print(s)
        weight(s)
    if(a=="volume converter"):
        print("The value to be converted is")
        with sr.Microphone() as source:
            audi = r.listen(source) 
        try:
            s=(r.recognize_google(audi,key=None,language="en-GB",show_all=False))
            print(s)
            f=open("unitconverterfile","a")
            f.write(s+"\n")
        except sr.UnknownValueError:
            s=("could not understand audio")
            print(s)
        except NameError:
            s=("could not understand audio")
            print(s)
        except LookupError:                            
            s=("Could not understand audio")
            print(s)
        volume(s)
    if(a=="area converter"):
        print("The value to be converted is")
        with sr.Microphone() as source:
            audi = r.listen(source) 
        try:
            s=(r.recognize_google(audi,key=None,language="en-GB",show_all=False))
            print(s)
            f=open("unitconverterfile","a")
            f.write(s+"\n")
        except sr.UnknownValueError:
            s=("could not understand audio")
            print(s)
        except NameError:
            s=("could not understand audio")
            print(s)
        except LookupError:                            
            s=("Could not understand audio")
            print(s)
        area(s)
    if(a=="currency converter"):
        print("The value to be converted is")
        with sr.Microphone() as source:
            audi = r.listen(source) 
        try:
            s=(r.recognize_google(audi,key=None,language="en-GB",show_all=False))
            print(s)
            f=open("unitconverterfile","a")
            f.write(s+"\n")
        except sr.UnknownValueError:
            s=("could not understand audio")
            print(s)
        except NameError:
            s=("could not understand audio")
            print(s)
        except LookupError:                            
            s=("Could not understand audio")
            print(s)
        currency(s)
    if(a=="time converter"):
        print("The value to be converted is")
        with sr.Microphone() as source:
            audi = r.listen(source) 
        try:
            s=(r.recognize_google(audi,key=None,language="en-GB",show_all=False))
            print(s)
            f=open("unitconverterfile","a")
            f.write(s+"\n")
        except sr.UnknownValueError:
            s=("could not understand audio")
            print(s)
        except NameError:
            s=("could not understand audio")
            print(s)
        except LookupError:                            
            s=("Could not understand audio")
            print(s)
        time(s)
    if(a=="speed converter"):
        print("The value to be converted is")
        with sr.Microphone() as source:
            audi = r.listen(source) 
        try:
            s=(r.recognize_google(audi,key=None,language="en-GB",show_all=False))
            print(s)
            f=open("unitconverterfile","a")
            f.write(s+"\n")
        except sr.UnknownValueError:
            s=("could not understand audio")
            print(s)
        except NameError:
            s=("could not understand audio")
            print(s)
        except LookupError:                            
            s=("Could not understand audio")
            print(s)
        speed(s)
    if(a=="force converter"):
        print("The value to be converted is")
        with sr.Microphone() as source:
            audi = r.listen(source) 
        try:
            s=(r.recognize_google(audi,key=None,language="en-GB",show_all=False))
            print(s)
            f=open("unitconverterfile","a")
            f.write(s+"\n")
        except sr.UnknownValueError:
            s=("could not understand audio")
            print(s)
        except NameError:
            s=("could not understand audio")
            print(s)
        except LookupError:                            
            s=("Could not understand audio")
            print(s)
        force(s)
else:
    print("Enter 1 for the length converter")
    print("Enter 2 for the weight converter")
    print("Enter 3 for the volume converter")
    print("Enter 4 for the area converter")
    print("Enter 5 for the currency converter")
    print("Enter 6 for the time converter")
    print("Enter 7 for the speed converter")
    print("Enter 8 for the force converter")
    print()
    v=int(input("Enter your choice: "))
    if(v==1):
        s=input("The value to be converted is:")
        f=open("unitconverterfile","a")
        f.write(s+"\n")
        length(s)
    if(v==2):
        s=input("The value to be converted is:")
        f=open("unitconverterfile","a")
        f.write(s+"\n")
        weight(s)
    if(v==3):
        s=input("The value to be converted is:")
        f=open("unitconverterfile","a")
        f.write(s+"\n")
        volume(s)
    if(v==4):
        s=input("The value to be converted is:")
        f=open("unitconverterfile","a")
        f.write(s+"\n")
        area(s)
    if(v==5):
        s=input("The value to be converted is:")
        f=open("unitconverterfile","a")
        f.write(s+"\n")
        currency(s)
    if(v==6):
        s=input("The value to be converted is:")
        f=open("unitconverterfile","a")
        f.write(s+"\n")
        time(s)
    if(v==7):
        s=input("The value to be converted is:")
        f=open("unitconverterfile","a")
        f.write(s+"\n")
        speed(s)
    if(v==8):
        s=input("The value to be converted is:")
        f=open("unitconverterfile","a")
        f.write(s+"\n")
        force(s)
# Out:
# The following converters are available:
# Length Converter
# Weight converter
# Volume Converter
# Area Converter
# Currency Converter
# Time Converter
# Force Converter
# If you want to use speech recognition enter 0 if not enter any other key
# 0
# Speak now
# which converter you want to use
